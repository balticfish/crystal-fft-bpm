# %%
import sys
XCr_path = '/Users/aliaksei/Downloads/lume-crystal-bpm'
sys.path.append(XCr_path)

import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from XCrystal import *
import time

import XCrTools as tools

# %%
delta_theta = 0.0
omega0 = 9000.0

xcr = XCrystal(XCr_path+'/Crystal.yaml', omega0)
xtools = tools.XCrTools(xcr)
# Out:
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Gaussian beam
# Initialized tools...

# %%
print('Bragg angle: ', xcr.alphaB * 180 / np.pi)
# Out:
# Bragg angle:  30.48558327729669

# %%
#xcr.dgrid_GenV2 = 1.2e-3
xcr.zsep_GenV2 = 1
    
field = pseudo_sase_beam.copy()

ntc, nxc, nyc = np.shape(field)
tmax = ntc * xcr.lam * xcr.zsep_GenV2 / xcr.c 
dt = tmax/(1.0*ntc)


pad_shape = [(xcr.tpad, xcr.tpad), (0, 0), (0, 0)]
field_padded = xtools.my_pad(field, pad_shape)
coeff = 2.0 * np.pi * xcr.hbar
w = np.fft.fftshift(coeff * np.fft.fftfreq(ntc + 2 * xcr.tpad, dt))
field_fft = np.fft.fftshift(np.fft.fft(field_padded, axis=0), axes=0)
print('padded field shape: ', np.shape(field_fft))

t_crop = 100
field_sim = xtools.crop_3d_wavefront(field_fft, cropping_factors=[t_crop, 1, 1])
w_sim = w[int(len(w)/2 - len(w)/t_crop/2):int(len(w)/2 + len(w)/t_crop/2)]
# Out:
# padded field shape:  (8292, 3200, 10)
# Cropped pump field to a new shape (t, x, y):  82 3200 10

# %%
import matplotlib.pyplot as plt
plt.title('loaded field spectral profile')
plt.plot(w_sim, np.sum(np.real(field_sim * np.conj(field_sim)), axis=(1,2)),'o-')
#plt.xlim(-10, 10)
plt.xlabel('Photon energy (eV)')
plt.ylabel('arb.')
# Out:
# Text(0, 0.5, 'arb.')

# %%
field = xtools.field_from_file_genesis2_DFL(xcr, crop_t = 1.0, crop_x = 1.0)

ntc, nxc, nyc = np.shape(field)
tmax = ntc * xcr.lam * xcr.zsep_GenV2 / xcr.c 
dt = tmax/(1.0*ntc)

old_domain = (np.linspace(-xcr.dgrid_GenV2*xcr.convr, xcr.dgrid_GenV2*xcr.convr, nxc), np.linspace(-xcr.dgrid_GenV2*xcr.convr, xcr.dgrid_GenV2*xcr.convr, nyc))
new_mesh = (xcr.Xx, xcr.Yy)
    
print('loaded field shape: ', np.shape(field))
print('simulation domain shape: ', np.shape(xcr.Xx))

pad_shape = [(xcr.tpad, xcr.tpad), (0, 0), (0, 0)]
field_padded = xtools.my_pad(field, pad_shape)
coeff = 2.0 * np.pi * xcr.hbar
w = np.fft.fftshift(coeff * np.fft.fftfreq(ntc + 2 * xcr.tpad, dt))
field_fft = np.fft.fftshift(np.fft.fft(field_padded, axis=0), axes=0)
print('padded field shape: ', np.shape(field_fft))

t_crop = 360
field_sim = xtools.crop_3d_wavefront(field_fft, cropping_factors=[t_crop, 1, 1])
w_sim = w[int(len(w)/2 - len(w)/t_crop/2):int(len(w)/2 + len(w)/t_crop/2)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-43c445eb3399> in <module>
# ----> 1 field = xtools.field_from_file_genesis2_DFL(xcr, crop_t = 1.0, crop_x = 1.0)
#       2
#       3 ntc, nxc, nyc = np.shape(field)
#       4 tmax = ntc * xcr.lam * xcr.zsep_GenV2 / xcr.c
#       5 dt = tmax/(1.0*ntc)
#
# ~/Downloads/lume-crystal-bpm/XCrTools.py in field_from_file_genesis2_DFL(self, XCr, crop_t, crop_x)
#      66         """
#      67
# ---> 68         dat = np.fromfile(XCr.fname_GenV2, dtype=np.complex).astype(np.complex)
#      69         npoints = dat.shape[0]
#      70         nx = XCr.ncar_GenV2
#
# AttributeError: 'XCrystal' object has no attribute 'fname_GenV2'

# %%
import matplotlib.pyplot as plt
plt.title('loaded field spectral profile')
plt.plot(w_sim, np.sum(np.real(field_sim * np.conj(field_sim)), axis=(1,2)),'o-')
#plt.xlim(-10, 10)
plt.xlabel('Photon energy (eV)')
plt.ylabel('arb.')
# Out:
# Text(0, 0.5, 'arb.')

# %%
Npoints = len(field_sim)
print(Npoints)
Rs = np.zeros(Npoints)
Ts = np.zeros(Npoints)
# Out:
# 23

# %%
def single_realization(delta_theta, w_ind):
    
    omega = omega0 + w_sim[w_ind]
    field_intrp = xtools.interpolate_wavefront_3D(field_fft[w_ind,:,:], old_domain, new_mesh)

    xcr = XCrystal(XCr_path+'/Crystal.yaml', omega)
    xcr.configure(delta_theta, field_intrp)
    xcr.run3D()
    
    return xcr.Reflectivity, xcr.Transmission

# %%
for i in range(0, Npoints):
    print(' ')
    print('iteration: ', i+1, '  dw: ', w_sim[i])
    Rs[i], Ts[i] = single_realization(delta_theta, i)
# Out:
#
# iteration:  1   dw:  -0.7041267643196033
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0.005860304081345583 ; Transmission:  0.6416037452331523
#
# iteration:  2   dw:  -0.678047995270729
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0.006038393347422949 ; Transmission:  0.6391062845464073
#
# iteration:  3   dw:  -0.6519692262218549
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0.0062839502288486535 ; Transmission:  0.6371202952584604
#
# iteration:  4   dw:  -0.6258904571729808
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0.00659375695839316 ; Transmission:  0.6359362974468824
#
# iteration:  5   dw:  -0.5998116881241065
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0.006949680299207858 ; Transmission:  0.6357792599099324
#
# iteration:  6   dw:  -0.5737329190752323
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0.007363986420179009 ; Transmission:  0.6367491722101002
#
# iteration:  7   dw:  -0.5476541500263581
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0.007834835699924329 ; Transmission:  0.6388525463761113
#
# iteration:  8   dw:  -0.5215753809774839
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0.008375590794006337 ; Transmission:  0.6419845402636907
#
# iteration:  9   dw:  -0.4954966119286097
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0.16184807504174703 ; Transmission:  0.4663841043505936
#
# iteration:  38   dw:  0.26078769048874195
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0.15165050539440494 ; Transmission:  0.48612849725699375
#
# iteration:  39   dw:  0.28686645953761614
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0.14095625507574547 ; Transmission:  0.5028074298688515
#
# iteration:  40   dw:  0.3129452285864904
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0.12666473807807074 ; Transmission:  0.5162708744289989
#
# iteration:  41   dw:  0.3390239976353645
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0.10572365668473759 ; Transmission:  0.5274602420911634
#
# iteration:  42   dw:  0.36510276668423874
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0.08230186630443963 ; Transmission:  0.5369160217834105
#
# iteration:  43   dw:  0.3911815357331129
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0.057006376880966124 ; Transmission:  0.5451302933516354
#
# iteration:  44   dw:  0.4172603047819871
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0.03886211713117563 ; Transmission:  0.5522303621431534
#
# iteration:  45   dw:  0.44333907383086135
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0.02864995523033571 ; Transmission:  0.5573756487679904
#
# iteration:  46   dw:  0.4694178428797355
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0.022746681160456528 ; Transmission:  0.5602625730287106
#
# iteration:  47   dw:  0.4954966119286097
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0.018799743594236147 ; Transmission:  0.5612047238062734
#
# iteration:  48   dw:  0.5215753809774839
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0.01635268006352839 ; Transmission:  0.560710283055183
#
# iteration:  49   dw:  0.5476541500263581
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0.014710595839141421 ; Transmission:  0.5595145180299526
#
# iteration:  50   dw:  0.5737329190752323
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0.01331900140983571 ; Transmission:  0.5583373999825989
#
# iteration:  51   dw:  0.5998116881241065
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0.011973054322477378 ; Transmission:  0.5577941198935129
#
# iteration:  52   dw:  0.6258904571729808
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0.010771985414443758 ; Transmission:  0.5582800041889674
#
# iteration:  53   dw:  0.6519692262218549
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0.009838338685163477 ; Transmission:  0.5600531352217465

# %%
matplotlib.rcParams['figure.figsize'] = (12,8)
matplotlib.rcParams['axes.labelsize'] = 20
matplotlib.rcParams['xtick.labelsize'] = 20
matplotlib.rcParams['ytick.labelsize'] = 20
matplotlib.rcParams['legend.fontsize'] = 20

# %%
# XOPfile = 'Si4009keVThickness50um'
# XOPdata = np.loadtxt(XOPfile)

# %%
# plt.plot(XOPdata[:,0]*4.848137, XOPdata[:,1], '-', linewidth=2.1, color='red', label='XOP')
# plt.plot(1e6 * delta_theta, Rs, 'o-', linewidth=1.0, color='black', label='Fast BPM')

plt.plot(w_sim, Rs, 'o-', linewidth=1.0, color='black', label='Fast BPM')


plt.legend()
#plt.xlabel(r'$\Delta \theta$ (urad)')
plt.ylabel('R')
# Out:
# Text(0, 0.5, 'R')

# %%
single_realization(delta_theta, 21)
# Out:
# Quiet mode disabled. I will talk a lot...
# Congigured grid parameters
# Congigured a Genesis2 beam
# Congigured deformation model
# Splitting recipe: Euler
# Initialized tools...
# Running with Genesis2 field
# Delta theta:  0.0 ; Reflectivity:  0.20832991132921236 ; Transmission:  0.4581268330434195
# (0.20832991132921236, 0.4581268330434195)
