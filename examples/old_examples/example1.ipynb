# %%
import sys
import os
XCr_path = os.getcwd()+'/../'
sys.path.append(XCr_path)

import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from XCrystal import *
import time

# %%
Npoints = 18
delta_theta = np.linspace(-13.862472049580001e-6, 41.54780686945001e-6, Npoints)  
omega0 = 9000.0
Rs = np.zeros(Npoints)
Ts = np.zeros(Npoints)

# %%
def single_realization(delta_theta, omega):
    
    xcr = XCrystal(XCr_path+'/config/Crystal.yaml', omega)
    xcr.configure(delta_theta)
    xcr.run3D()
    
    return xcr.Reflectivity, xcr.Transmission

# %%
for i in range(0, Npoints):
    Rs[i], Ts[i] = single_realization(delta_theta[i], omega0)
# Out:
# Delta theta:  -1.3862472049580001e-05 ; Reflectivity:  0.020695085508307953 ; Transmission:  0.42040038203354957
# Delta theta:  -1.0603043877872354e-05 ; Reflectivity:  0.03789692942428667 ; Transmission:  0.42281137625037307
# Delta theta:  -7.343615706164705e-06 ; Reflectivity:  0.060329225304535425 ; Transmission:  0.4245779323066934
# Delta theta:  -4.084187534457056e-06 ; Reflectivity:  0.07079215569078383 ; Transmission:  0.4342237803799114
# Delta theta:  -8.247593627494089e-07 ; Reflectivity:  0.0334520542623599 ; Transmission:  0.4722378826181255
# Delta theta:  2.4346688089582383e-06 ; Reflectivity:  0.1822246138668329 ; Transmission:  0.424238609903499
# Delta theta:  5.694096980665889e-06 ; Reflectivity:  0.4132376722523215 ; Transmission:  0.3079839640446249
# Delta theta:  8.953525152373536e-06 ; Reflectivity:  0.9636387819605411 ; Transmission:  7.392211581857722e-06
# Delta theta:  1.2212953324081183e-05 ; Reflectivity:  0.9415478188998879 ; Transmission:  3.6451267869646456e-06
# Delta theta:  1.547238149578883e-05 ; Reflectivity:  0.9111918283982432 ; Transmission:  2.8462296990050587e-06
# Delta theta:  1.8731809667496478e-05 ; Reflectivity:  0.8434990717469356 ; Transmission:  2.933789915024792e-06
# Delta theta:  2.1991237839204125e-05 ; Reflectivity:  0.3195505367161658 ; Transmission:  0.015412540022940057
# Delta theta:  2.525066601091178e-05 ; Reflectivity:  0.14035766172170328 ; Transmission:  0.1012750220970958
# Delta theta:  2.8510094182619426e-05 ; Reflectivity:  0.050328675527466275 ; Transmission:  0.1680177583047085
# Delta theta:  3.176952235432707e-05 ; Reflectivity:  0.05362884411886156 ; Transmission:  0.2024554144736628
# Delta theta:  3.502895052603472e-05 ; Reflectivity:  0.05058992737987708 ; Transmission:  0.22647302697494123
# Delta theta:  3.8288378697742364e-05 ; Reflectivity:  0.038361288291069814 ; Transmission:  0.2465247053229943
# Delta theta:  4.154780686945001e-05 ; Reflectivity:  0.025910139552438337 ; Transmission:  0.2630255741759608

# %%
matplotlib.rcParams['figure.figsize'] = (12,8)
matplotlib.rcParams['axes.labelsize'] = 20
matplotlib.rcParams['xtick.labelsize'] = 20
matplotlib.rcParams['ytick.labelsize'] = 20
matplotlib.rcParams['legend.fontsize'] = 20

# %%
XOPfile = 'Si4009keVThickness50um'
XOPdata = np.loadtxt(XOPfile)

# %%
plt.plot(XOPdata[:,0]*4.848137, XOPdata[:,1], '-', linewidth=2.1, color='red', label='XOP')
plt.plot(1e6 * delta_theta, Rs, '.-', linewidth=2.0, color='blue', label='Fast BPM')


plt.legend()
plt.xlabel(r'$\Delta \theta$ (urad)')
plt.ylabel('R')
# Out:
# Text(0, 0.5, 'R')
