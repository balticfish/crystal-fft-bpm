# %%
import sys
import os
XCr_path = os.getcwd()+'/../'
sys.path.append(XCr_path)

import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from XCrystal import *
import time

# %%
XCr_path
# Out:
# '/sdf/group/ad/beamphysics/fft-bpm/CrystalBPM_10_07_2025P/examples/../'

# %%
xcr = XCrystal(XCr_path+'/config/Si44417keVConstanStrainGradient.yaml')
xcr.convr
xcr.omega0
# Out:
# 17000.0

# %%
def single_realization(delta_theta, omega):
    
    xcr = XCrystal(XCr_path+'/Si44417keVConstanStrainGradient.yaml', omega)
    xcr.configure(delta_theta)
    xcr.run3D()
    
    return xcr.Reflectivity, xcr.Transmission

def single_realization_with_data(delta_theta,omega):
    
    xcr = XCrystal(XCr_path+'/config/Si44417keVConstanStrainGradient.yaml')
    xcr.configure(delta_theta,0)
    xcr.run3D()
    
    return xcr.Reflectivity, xcr.Transmission, xcr.U1_field, xcr.U2_field, xcr.u, xcr.M

# %%
U1_data = []
U2_data = []

Rs, Ts, U1_xyz, U2_xyz, up, MM = single_realization_with_data(-22e-6,xcr.omega0)
U1_data.append(U1_xyz)
U2_data.append(U2_xyz)

U1_xyz = np.asarray(U1_data)
U2_xyz = np.asarray(U2_data)
# Out:
# Beam propagation progress:   0%|          | 1/504 [00:00<00:04, 101.01it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 4
#       1 U1_data = []
#       2 U2_data = []
# ----> 4 Rs, Ts, U1_xyz, U2_xyz, up, MM = single_realization_with_data(-22e-6,xcr.omega0)
#       5 U1_data.append(U1_xyz)
#       6 U2_data.append(U2_xyz)
#
# Cell In[18], line 13, in single_realization_with_data(delta_theta, omega)
#      11 xcr = XCrystal(XCr_path+'/config/Si44417keVConstanStrainGradient.yaml')
#      12 xcr.configure(delta_theta,0)
# ---> 13 xcr.run3D()
#      15 return xcr.Reflectivity, xcr.Transmission, xcr.U1_field, xcr.U2_field, xcr.u, xcr.M
#
# File /sdf/group/ad/beamphysics/fft-bpm/CrystalBPM_10_07_2025P/examples/../XCrystal.py:436, in XCrystal.run3D(self)
#     433 U1i = 0.0 * xbpm.E_in.copy()
#     434 U2i = 1.0 * xbpm.E_in.copy()
# --> 436 U1f, U2f = xbpm.propagate_with_split_operator_BPM(self, U1i, U2i)
#     438 if self.asymm_angle <= 0.0:
#     439     Erefl=np.sum(((self.Xx)<(self.xs-self.HH))*np.abs(U1f)**2)
#
# File /sdf/group/ad/beamphysics/fft-bpm/CrystalBPM_10_07_2025P/examples/../XBPM.py:172, in XBPM.propagate_with_split_operator_BPM(self, XCr, U1R, U2R)
#     169 op_cff = len(XCr.c_i) - 1 - i
#     171 if XCr.d_i[op_cff] != 0:
# --> 172     U1, U2 = self.operator_B(U1, U2, [XCr, k, XCr.d_i[op_cff]])
#     173 else:
#     174     U1 = U1
#
# File /sdf/group/ad/beamphysics/fft-bpm/CrystalBPM_10_07_2025P/examples/../XBPM.py:149, in XBPM.operator_B(self, U1prop, U2prop, params)
#     147 dz_store = self.Dz0(XCr,[d_i,k]) # stored for later use
#     148 ksh_store = self.ksih0_select(XCr,[d_i,k]) # stored for later use
# --> 149 ksih1_m = self.ksih1_p_select(XCr,[d_i,k])* np.exp(2j * XCr.k0 *self.u[:,:,k])
#     150 ksih1_p = self.ksih1_p_select(XCr,[d_i,k])* np.exp(-2j * XCr.k0 *self.u[:,:,k])
#     151 U1prop *= dz_store
#
# IndexError: index 1 is out of bounds for axis 2 with size 1

# %%
xcr.u.size

# %%
kmax=U1_xyz.shape[3]
kmax

# %%
logh1=((xcr.Xx-xcr.sep1) >= (-xcr.HH )) * ((xcr.Xx-xcr.sep1) <=(xcr.HH ))
logh2=((xcr.Xx-xcr.sep1) >= (-xcr.HH*0.9 )) * ((xcr.Xx-xcr.sep1) <=(xcr.HH*0.9 ))
logh1h2=logh1^logh2
logh1h2.shape
xcr.Xx.shape

# %%
log_hJ=np.zeros((xcr.xgrid,kmax))      
for i in range(xcr.xgrid):
    for k in range(kmax):
        log_hJ[i,k]=logh1h2[i]

# %%
plt.imshow(np.abs(U1_xyz[0,:,0,:]**2 + U2_xyz[0,:,0,:]**2), aspect='auto',cmap='jet')
plt.imshow(log_hJ, aspect='auto',cmap='jet', alpha=0.2)

# %%
2+2
