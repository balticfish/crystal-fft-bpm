# %%
pwd
# Out:
# '/sdf/group/ad/beamphysics/fft-bpm/CrystalBPM_10_07_2025P/examples'

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
matplotlib.rcParams['figure.figsize'] = (8,7)
matplotlib.rcParams['axes.labelsize'] = 20
matplotlib.rcParams['xtick.labelsize'] = 20
matplotlib.rcParams['ytick.labelsize'] = 20
matplotlib.rcParams['legend.fontsize'] = 20

# %%
import sys
import os
XCr_path = os.getcwd()+'/../'
sys.path.append(XCr_path)
from XCrystal import *
import XCrTools as tools
omega0 = 12800.0

xcr = XCrystal(XCr_path+'/config/C333_Omega12p8keV_waist250um.yaml', omega0)
xtools = tools.XCrTools(xcr)

# %%
pwd
# Out:
# '/sdf/group/ad/beamphysics/fft-bpm/CrystalBPM_10_07_2025P/examples'

# %%
ls ru*
# Out:
# run_2_64_angleC440_14p4keVR65.npy
# run_2_64_angleC440_14p4keVR95.npy
# run_8_16_angleC400_9p8keV_Laue_waist2000um_thick_82_90p00deg.npy
# run_omega_U1_1_36_angleC400_Asym-sphere.npy
# run_omega_U1_1_36_angleFiniteCrystal_Si440_60deg_Dislocation.npy
# run_omega_U1_1_64_angleFiniteCrystal_Si440_60deg_Dislocation.npy
# run_omega_U1_17_42_C400_9831eVBump.npy
# run_omega_U1_22_42_C333_12800_eVm6p0urad10fstmax1300xgrid2400waist50zsep100Thickness50umsigmat10fstp.npy
# run_omega_U1_22_42_C333_12800_eVm6p0urad10fstmax1300xgrid2400waist50zsep100Thickness50umsigmat20fstp.npy
# run_omega_U1_22_42_C333_12800_eVm6p0urad10fstmax1300xgrid2400waist50zsep100Thickness50umsigmat50fstp.npy
# run_omega_U1_2_32_angleFiniteCrystal_Si440_60deg_Dislocation.npy
# run_omega_U1_25_42_C333_12800_eVm6p0urad10fstmax1300xgrid2400waist50zsep100Thickness50umsigmat50fs.npy
# run_omega_U1_26_16_C333_12800_eVm6p0urad10fstmax1300xgrid2400waist250zsep100Thickness50um.npy
# run_omega_U1_26_16_C333_12800_eVm6p0urad10fstmax1300xgrid2400waist50zsep100Thickness50um.npy
# run_omega_U1_26_16_C333_12800_eVm6p0urad10fstmax1300xgrid2400waist50zsep100Thickness50umsigmat100fs.npy
# run_omega_U1_46_16_C400_9831eVBump.npy
# run_omega_U1_46_16_C400_9831eVBumptest.npy
# run_omega_U1_51_42_C333_12800_eVm6p0urad10fstmax1300xgrid2400waist50zsep100Thickness50umsigmat50fs.npy
# run_omega_U1_67_16_C333_12800_eVm6p0urad10fstmax1300xgrid2400waist50zsep100Thickness50umsigmat50fs.npy
# run_omega_U2_1_36_angleFiniteCrystal_Si440_60deg_Dislocation.npy
# run_omega_U2_1_64_angleFiniteCrystal_Si440_60deg_Dislocation.npy
# run_omega_U2_17_42_C400_9831eVBump.npy
# run_omega_U2_22_42_C333_12800_eVm6p0urad10fstmax1300xgrid2400waist50zsep100Thickness50umsigmat10fstp.npy
# run_omega_U2_22_42_C333_12800_eVm6p0urad10fstmax1300xgrid2400waist50zsep100Thickness50umsigmat20fstp.npy
# run_omega_U2_22_42_C333_12800_eVm6p0urad10fstmax1300xgrid2400waist50zsep100Thickness50umsigmat50fstp.npy
# run_omega_U2_2_32_angleFiniteCrystal_Si440_60deg_Dislocation.npy
# run_omega_U2_25_42_C333_12800_eVm6p0urad10fstmax1300xgrid2400waist50zsep100Thickness50umsigmat50fs.npy
# run_omega_U2_26_16_C333_12800_eVm6p0urad10fstmax1300xgrid2400waist250zsep100Thickness50um.npy
# run_omega_U2_26_16_C333_12800_eVm6p0urad10fstmax1300xgrid2400waist50zsep100Thickness50um.npy
# run_omega_U2_26_16_C333_12800_eVm6p0urad10fstmax1300xgrid2400waist50zsep100Thickness50umsigmat100fs.npy
# run_omega_U2_46_16_C400_9831eVBump.npy
# run_omega_U2_46_16_C400_9831eVBumptest.npy
# run_omega_U2_51_42_C333_12800_eVm6p0urad10fstmax1300xgrid2400waist50zsep100Thickness50umsigmat50fs.npy
# run_omega_U2_67_16_C333_12800_eVm6p0urad10fstmax1300xgrid2400waist50zsep100Thickness50umsigmat50fs.npy
# run_parallel_angleC400_9831eV_Laue.py
# run_parallel_angleC400_9p8keV_Laue_Asym-sphere.py
# run_parallel_angleC440CurvedSpectrometer.py
# run_parallel_angle_scanFiniteCrystal_Si440_60deg_Dislocation.py
# run_parallel-omegaC333.py
# run_parallel_TD_deformed.py

# %%
U1file = 'run_omega_U1_26_16_C333_12800_eVm6p0urad10fstmax1300xgrid2400waist250zsep100Thickness50um.npy'
U2file = 'run_omega_U2_26_16_C333_12800_eVm6p0urad10fstmax1300xgrid2400waist250zsep100Thickness50um.npy'

U1_wxyz = np.load(U1file)
U2_wxyz = np.load(U2file)

# %%
U1_wxyz.shape
xcr.configure(8e-6,xcr.omega0)
# Out:
# No deformation model was selected

# %%
IJ=33

# %%
#extent = [0, xcr.xxmax / xcr.convr * 1e6, np.max(w_sim), np.min(w_sim)]
#GnBu
plt.figure(figsize=(5,4))
plt.imshow(np.abs(U1_wxyz[:,:,0,IJ])**1 + np.abs(U2_wxyz[:,:,0,IJ])**1, aspect='auto', cmap='jet')
plt.xlabel(r'X ($\mu$m)')
plt.ylabel(r'$\Delta \omega$ (eV)')
#plt.plot(100*XOPdata[:,1], dw, '-', linewidth=2.1, color='red')
#plt.plot(np.abs(E_wxy_padded[:, 1600, 5])*3e4, w, '-.', color='blue')

#U1_wxyz#plt.ylim(-0.5, 0.5)
# Out:
# Text(0, 0.5, '$\\Delta \\omega$ (eV)')

# %%
U1_wx = U1_wxyz[:, :, 0, :]
U2_wx = U2_wxyz[:, :, 0, :]

U1_tx = np.fft.ifft(U1_wx, axis=0)
U2_tx = np.fft.ifft(U2_wx, axis=0)
#U1_tx=np.roll(U1_tx, shift=-100, axis=0)
#U2_tx=np.roll(U2_tx, shift=-100, axis=0)

# %%
It=33
U1_txIt=U1_tx[:,:,It];
U2_txIt=U2_tx[:,:,It];
plt.figure(figsize=(6,5))
plt.imshow(np.abs(U1_txIt*1+U2_txIt*1)**0.7, aspect='auto')
plt.ylabel(r'$\Delta t$ (a.u.)')
#plt.ylim(400,100)
#plt.xlim(1000,3000)
#plt.grid()
plt.show()

# %%
fig, ax = plt.subplots()
ax.imshow(np.abs(U2_txIt)*0+np.abs(U1_txIt)**0.5,extent=[-xcr.xxmax / xcr.convr * 1e6, xcr.xxmax / xcr.convr * 1e6, 0, 200], aspect='auto', cmap='jet')

#ax.set_xlim(100,700)
ax.set_ylim(95, 135)
plt.show()

# %%
xcr.xxmax/xcr.convr
# Out:
# 0.001

# %% [markdown]
# #### extent = [0, xcr.xxmax / xcr.convr * 1e6, np.max(w_sim), np.min(w_sim)]
# #GnBu
# plt.figure(figsize=(10,8))
# plt.imshow(np.abs(U2_wxyz[:,:,0,31])**1, aspect='auto', cmap='jet')
# plt.xlabel(r'X ($\mu$m)')
# plt.ylabel(r'$\Delta \omega$ (eV)')
# #plt.plot(100*XOPdata[:,1], dw, '-', linewidth=2.1, color='red')
# #plt.plot(np.abs(E_wxy_padded[:, 1600, 5])*3e4, w, '-.', color='blue')
#
# #U1_wxyz#plt.ylim(-0.5, 0.5)

# %%
#extent = [0, xcr.xxmax / xcr.convr * 1e6, np.max(w_sim), np.min(w_sim)]
#GnBu
plt.figure(figsize=(10,8))
plt.imshow(np.abs(U1_wxyz[:,:,0,31])**1, aspect='auto', cmap='jet')
plt.xlabel(r'X ($\mu$m)')
plt.ylabel(r'$\Delta \omega$ (eV)')
#plt.plot(100*XOPdata[:,1], dw, '-', linewidth=2.1, color='red')
#plt.plot(np.abs(E_wxy_padded[:, 1600, 5])*3e4, w, '-.', color='blue')

#U1_wxyz#plt.ylim(-0.5, 0.5)
# Out:
# Text(0, 0.5, '$\\Delta \\omega$ (eV)')

# %%
12*26/60
# Out:
# 5.2

# %%
12*26
# Out:
# 312
