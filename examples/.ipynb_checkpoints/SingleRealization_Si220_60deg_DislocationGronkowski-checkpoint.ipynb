# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import time
XCr_path = os.getcwd()+'/../'
sys.path.append(XCr_path)
from XCrystal import *
t0 = time.time()

# %%
xcr = XCrystal(XCr_path+'/config/Si200_17p45keVDislk60degGronkowski.yaml')
pp=xcr.configure(0)
pp

# %%
def single_realization_with_data(delta_theta,omega):
    
    xcr = XCrystal(XCr_path+'/config/Si200_17p45keVDislk60degGronkowski.yaml',omega)
    xcr.configure(delta_theta)
    xcr.run3D()
    return xcr.Reflectivity, xcr.Transmission, xcr.U1_field, xcr.U2_field, xcr.u, xcr.M

# %%
omega0=17450

# %%
U1_data = []
U2_data = []

Rs, Ts, U1_xyz, U2_xyz, up, MM = single_realization_with_data(0e-6,omega0)
U1_data.append(U1_xyz)
U2_data.append(U2_xyz)

U1_xyz = np.asarray(U1_data)
U2_xyz = np.asarray(U2_data)
# Out:
# Omega:  17450 ; Reflectivity:  0.0017784492191303784 ; Transmission:  0.0047602669071084005

# %%
 U2_xyz.shape
# Out:
# (1, 250, 150, 501)

# %%
p=1
plt.imshow(np.abs(U1_xyz[0,50,:,0:xcr.M-1]*1 + U2_xyz[0,50,:,0:xcr.M-1]*1)**0.5*(1))
#plt.imshow(np.abs(U1_xyz[0,:,0,:])**2 + np.abs(U2_xyz[0,:,0,:])**2,extent=[0,xcr.M*xcr.Z/xcr.convr*1e6,0,xcr.xx.max()*2/xcr.convr*1e6], aspect='auto',cmap='jet')
#plt.ylim(350, 800)
#plt.xlim(0,300)
plt.ylabel(r'x  ( $\mu$m)')
plt.xlabel(r'z  ( $\mu$m)')
xcr.M*xcr.Z/xcr.convr*1e6
# Out:
# 558.3951377543045

# %%
plt.plot(np.abs(U1_xyz[0,2,:,9]*1 + U2_xyz[0,2,:,9]*0)**0.5*(1))

# %% [markdown]
# ##

# %%
p=100
iIndx=1
wM=xcr.M-1
plt.imshow(np.abs(U1_xyz[0,iIndx,:,0:wM]*1 + U2_xyz[0,iIndx,:,0:wM]*1)**2*xcr.u[iIndx,:,0:wM]**0,extent=[-3,xcr.M*xcr.Z/xcr.convr*1e6/36.3-3,-xcr.yy.max()*2/xcr.convr*1e6/2,xcr.yy.max()*2/xcr.convr*1e6/2], aspect='auto',cmap='gray')
#plt.imshow(np.abs(U1_xyz[0,:,0,:])**2 + np.abs(U2_xyz[0,:,0,:])**2,extent=[0,xcr.M*xcr.Z/xcr.convr*1e6,0,xcr.xx.max()*2/xcr.convr*1e6], aspect='auto',cmap='jet')
#plt.ylim(-2.8,2.8)
#plt.xlim(0,10)
plt.ylabel(r'y  ( $\mu$m)')
plt.xlabel(r'z  ( $\mu$m)')
# Out:
# Text(0.5, 0, 'z  ( $\\mu$m)')

# %%
 U2_xyz.shape
# Out:
# (1, 250, 150, 501)

# %%
xcr.M
# Out:
# 500

# %%
pp=499
ints=np.abs(U1_xyz[0,:,:,pp]*1 + U2_xyz[0,:,:,pp]*0)**(2)
ints=np.transpose(ints)
#ints=np.flipud(ints)
ints=np.fliplr(ints)
plt.imshow(1*(1-np.exp(-80*ints)),extent=[-xcr.xx.max()/xcr.convr*1e6,xcr.xx.max()/xcr.convr*1e6,xcr.yy.min()/xcr.convr*1e6,xcr.yy.max()/xcr.convr*1e6], aspect='auto',cmap='gray_r')
#plt.ylim(150, 500)
#plt.xlim(200,700)
plt.ylabel(r'y  ( $\mu$m)')
plt.xlabel(r'x  ( $\mu$m)')
plt.colorbar()

# %%
xcr.slit_x/xcr.convr
# Out:
# 1.0764066378386698e-05

# %%
plt.imshow(ints, aspect='auto',cmap='gray_r')
plt.colorbar()

# %%
xcr.x0dm
# Out:
# 0

# %%
from mpl_toolkits import mplot3d
fig = plt.figure()
ax = plt.axes(projection='3d')
Z=(1-np.exp(-5*ints))
X, Y = np.meshgrid(xcr.xx/xcr.convr*1e6,xcr.yy/xcr.convr*1e6)
ax.plot_surface(X,Y,Z, rstride=1, cstride=1,
                cmap='jet', edgecolor='none')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');
ax.view_init(80, 60)

# %%
np.argmax(ints)
indices = np.where(ints == ints.max())
indices, np.shape(ints)
# Out:
# ((array([26]), array([177])), (150, 250))

# %% [markdown]
# x0d: 20
# y0d: -0 #y coordinate of dislocatio in um
# z0d: -40 #z coordinate of dislocatio in um

# %%
xcr.xgrid
# Out:
# 250

# %%
iIndx=30
xcr.u.shape
xcr.xx[iIndx]/xcr.convr*1e6
# Out:
# -303.6144578313253

# %%
p=50
plt.imshow(xcr.u[:,p,0:xcr.M-1],extent=[0,xcr.M*xcr.Z/xcr.convr*1e6,0,xcr.xx.max()*2/xcr.convr*1e6], aspect='auto',cmap='jet')
#plt.imshow(np.abs(U1_xyz[0,:,0,:])**2 + np.abs(U2_xyz[0,:,0,:])**2,extent=[0,xcr.M*xcr.Z/xcr.convr*1e6,0,xcr.xx.max()*2/xcr.convr*1e6], aspect='auto',cmap='jet')
#plt.ylim(350, 800)
#plt.xlim(0,300)
plt.ylabel(r'x  ( $\mu$m)')
plt.xlabel(r'z  ( $\mu$m)')
xcr.M*xcr.Z/xcr.convr*1e6
xcr.u.shape
# Out:
# (250, 150, 500)

# %%
iIndx=125
plt.imshow(xcr.u[iIndx,:,:],extent=[0,xcr.M*xcr.Z/xcr.convr*1e6,-xcr.yy.max()/xcr.convr*1e6,xcr.yy.max()/xcr.convr*1e6], aspect='auto',cmap='jet')

# %%
plt.imshow(xcr.u[:,:,350],extent=[0,xcr.xx.max()*2/xcr.convr*1e6,0,xcr.yy.max()*2/xcr.convr*1e6], aspect='auto',cmap='jet')
#plt.ylim(20, 40)
#plt.xlim(480,500)

# %%
t1 = time.time()  
print('Time (min):', (t1 - t0)/60)
# Out:
# Time (min): 6.100565807024638

# %%
np.tan(np.pi/180*20)
# Out:
# 0.36397023426620234

# %%
U1_xyz.shape
# Out:
# (1, 250, 150, 501)

# %%
p=10
wM=xcr.M-1
plt.imshow(ints, extent=[0,xcr.M*xcr.Z/xcr.convr*1e6,-xcr.xx.max()/xcr.convr*1e6,xcr.xx.max()/xcr.convr*1e6],aspect='auto',cmap='gray_r')
#plt.xlim(0,100)
#plt.imshow(np.abs(U1_xyz[0,:,p,0:wM]*1 + U2_xyz[0,:,p,0:wM]*0), aspect='auto',cmap='jet')
plt.ylabel(r'x  ( $\mu$m)')
(r'z  ( $\mu$m)')
#plt.ylim(-100,100)
# Out:
# 'z  ( $\\mu$m)'

# %%
p=50
wM=xcr.M-1
plt.imshow(np.abs(0*U1_xyz[0,p,:,0:wM])**0.9 + 1*np.abs(U2_xyz[0,p,:,0:wM])**0.9)
#plt.xlim(177,194)
#plt.imshow(np.abs(U1_xyz[0,:,p,0:wM]*1 + U2_xyz[0,:,p,0:wM]*0), aspect='auto',cmap='jet')
plt.ylabel(r'x  ( $\mu$m)')
plt.xlabel(r'z  ( $\mu$m)')
# Out:
# Text(0.5, 0, 'z  ( $\\mu$m)')

# %%
1.7834097308427/np.sqrt(2)
# Out:
# 1.2610611143129486

# %%
xcr.x00/np.tan(xcr.alpha)/xcr.convr*1e6
# Out:
# -75.31812598103511

# %%
min(xcr.z1[:])/xcr.convr*1e6
# Out:
# -75.31812598103511

# %%
xcr.z0/xcr.convr*1e6
# Out:
# 75.31812598103511

# %%
xcr.x00/xcr.convr*1e6
# Out:
# -29.999999999999996

# %%
import sys
sys.version_info
# Out:
# sys.version_info(major=3, minor=11, micro=7, releaselevel='final', serial=0)

# %%
print(sys.version)
# Out:
# 3.11.7 | packaged by conda-forge | (main, Dec 23 2023, 14:43:09) [GCC 12.3.0]
