# %%
import sys
import os
XCr_path = os.getcwd()+'/../'
sys.path.append(XCr_path)

import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from XCrystal import *
import time

# %%
Npoints = 18
delta_theta = np.linspace(-13.862472049580001e-6, 41.54780686945001e-6, Npoints)  
omega0 = 9000.0
Rs = np.zeros(Npoints)
Ts = np.zeros(Npoints)

# %%
def single_realization(delta_theta, omega):
    
    xcr = XCrystal(XCr_path+'/config/Si400_9keV.yaml', omega)
    xcr.configure(delta_theta)
    xcr.run3D()
    
    return xcr.Reflectivity, xcr.Transmission

# %%
for i in range(0, Npoints):
    Rs[i], Ts[i] = single_realization(delta_theta[i], omega0)
# Out:
# Delta theta:  -1.3862472049580001e-05 ; Reflectivity:  0.020983553847895433 ; Transmission:  0.4290754230672133 PhaseRefl 0.8453886462697523
# Delta theta:  -1.0603043877872354e-05 ; Reflectivity:  0.03657169689159377 ; Transmission:  0.43195797135131503 PhaseRefl 0.32216678398462234
# Delta theta:  -7.343615706164705e-06 ; Reflectivity:  0.05562058639774498 ; Transmission:  0.4351260067045214 PhaseRefl -2.536164485423726
# Delta theta:  -4.084187534457056e-06 ; Reflectivity:  0.062168221860664674 ; Transmission:  0.4469118197057373 PhaseRefl 0.7305030145759982
# Delta theta:  -8.247593627494089e-07 ; Reflectivity:  0.035876202096737704 ; Transmission:  0.48070134372955337 PhaseRefl -2.5676208630350597
# Delta theta:  2.4346688089582383e-06 ; Reflectivity:  0.1924566955422505 ; Transmission:  0.42749227364606024 PhaseRefl -2.4978737126967054
# Delta theta:  5.694096980665889e-06 ; Reflectivity:  0.43861676044875253 ; Transmission:  0.3036640530878971 PhaseRefl 0.6040927131611974
# Delta theta:  8.953525152373536e-06 ; Reflectivity:  0.9644910690322982 ; Transmission:  3.4969807880775004e-05 PhaseRefl -2.197922445598593
# Delta theta:  1.2212953324081183e-05 ; Reflectivity:  0.9415699664677296 ; Transmission:  4.051522647153236e-05 PhaseRefl 2.3490325081134094
# Delta theta:  1.547238149578883e-05 ; Reflectivity:  0.9102866797885775 ; Transmission:  4.565972969233982e-05 PhaseRefl 0.3472456678819962
# Delta theta:  1.8731809667496478e-05 ; Reflectivity:  0.8390971282600846 ; Transmission:  4.998739024462224e-05 PhaseRefl -2.741276740400683
# Delta theta:  2.1991237839204125e-05 ; Reflectivity:  0.2965145778967454 ; Transmission:  0.018793990403561653 PhaseRefl 0.3800152885421618
# Delta theta:  2.525066601091178e-05 ; Reflectivity:  0.12216598907357237 ; Transmission:  0.1077466624896894 PhaseRefl -2.801688708572966
# Delta theta:  2.8510094182619426e-05 ; Reflectivity:  0.05258972837144294 ; Transmission:  0.17222047966887805 PhaseRefl 0.2935480171148168
# Delta theta:  3.176952235432707e-05 ; Reflectivity:  0.05234665839904199 ; Transmission:  0.20689754345904612 PhaseRefl -2.895116923456476
# Delta theta:  3.502895052603472e-05 ; Reflectivity:  0.04251450542284625 ; Transmission:  0.23244644158627803 PhaseRefl 0.20170072512903256
# Delta theta:  3.8288378697742364e-05 ; Reflectivity:  0.028626102853260095 ; Transmission:  0.2530551539101118 PhaseRefl -2.980727931323212
# Delta theta:  4.154780686945001e-05 ; Reflectivity:  0.01775468587186416 ; Transmission:  0.26921626111008096 PhaseRefl 0.12476041481841615

# %%
matplotlib.rcParams['figure.figsize'] = (12,8)
matplotlib.rcParams['axes.labelsize'] = 20
matplotlib.rcParams['xtick.labelsize'] = 20
matplotlib.rcParams['ytick.labelsize'] = 20
matplotlib.rcParams['legend.fontsize'] = 20

# %%
XOPfile = 'Si4009keVThickness50um'
XOPdata = np.loadtxt(XOPfile)

# %%
plt.plot(XOPdata[:,0]*4.848137, XOPdata[:,1], '-', linewidth=2.1, color='red', label='XOP')
plt.plot(1e6 * delta_theta, Rs, 'o', linewidth=2.0, color='blue', label='Fast BPM')


plt.legend()
plt.xlabel(r'$\Delta \theta$ (urad)')
plt.ylabel('R')
# Out:
# Text(0, 0.5, 'R')
