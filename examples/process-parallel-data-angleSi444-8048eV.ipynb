# %%
import sys
import os
XCr_path = os.getcwd()+'/../'
sys.path.append(XCr_path)

import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from XCrystal import *
import time

# %%
pwd
# Out:
# '/global/cscratch1/sd/krzywins/CRYSTALBPMExpl/crystal-fft-bpm/examples'

# %%
matplotlib.rcParams['figure.figsize'] = (12,8)
matplotlib.rcParams['axes.labelsize'] = 20
matplotlib.rcParams['xtick.labelsize'] = 20
matplotlib.rcParams['ytick.labelsize'] = 20
matplotlib.rcParams['legend.fontsize'] = 20

# %%
datafile1 =XCr_path + 'examples/run_24_16_angle_Si_444_8048_eV.npy'
# datafile2 = 'run_8_16_Silicon_004_12000_eV_FR3_sqrt2.npy'
# datafile3 = 'run_8_16_Silicon_004_12000_eV_HS_coeff.npy'

# %%
full_run1 = np.load(datafile1)
# full_run2 = np.load(datafile2)
# full_run3 = np.load(datafile3)


n_cycle, n_par, n_data = np.shape(full_run1)
n_cycle, n_par, n_data
# Out:
# (24, 16, 3)

# %%
XOPfile = XCr_path +'/examples/Si444_50um'

XOPdata = np.loadtxt(XOPfile)

# %%
min_theta = np.min(XOPdata[:,0])
max_theta = np.max(XOPdata[:,0])

# %%
min_theta, max_theta
# Out:
# (-2.20673, 19.3745)

# %%
len(XOPdata)
# Out:
# 600

# %%
RCI_data1 = np.reshape(full_run1, (n_cycle * n_par, n_data))

# %%
plt.plot(1e6 * RCI_data1[:,0], RCI_data1[:,1], '+-', linewidth=3.1, color='b', label='FFT BPM')

plt.plot(XOPdata[:,0]*4.848, XOPdata[:,1], '-', linewidth=2.1, color='red', label='XOP')

plt.legend()

plt.xlabel(r'$\Delta \theta$ (urad)')
plt.ylabel('R')
plt.ylim(0.0, 1.1)
# Out:
# (0.0, 1.1)

# %%
 -0.151703E-04/2,   -0.350996E-06/2
# Out:
# (-7.58515e-06, -1.75498e-07)
